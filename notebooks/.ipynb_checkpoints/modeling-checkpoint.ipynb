# %% [markdown]
# # Modeling
#
# Pada tahapan ini dilakukan pemodelan pada dataset yang sudah dilakukan preprocessing sebelumnya.

# %% [markdown]
# ## Hyperparameter Tuning Random Forest

# %% [markdown]
# ### Random Forest with SMOTE

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model
rf = RandomForestClassifier(random_state=42)

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Inisialisasi GridSearchCV
grid_search_rf_smote = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2 
)


start = time.time()
# Jalankan GridSearch
grid_search_rf_smote.fit(X_train_smote, y_train_smote)

end = time.time()
duration = end - start

# Tampilkan hasil terbaik
print("Best Params:", grid_search_rf_smote.best_params_)
print("Best Cross-Validated Accuracy:", grid_search_rf_smote.best_score_)
print(f"Durasi training: {duration:.2f} detik")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 8.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 4.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 8.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.2min
# Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best Cross-Validated Accuracy: 0.9997790089630503
# Durasi training: 4643.86 detik
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 4.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.7min

# %%
print("Best Params:", grid_search_rf_smote.best_params_)
# Out:
# Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
grid_search_rf_smote.get_params()
# Out:
# {'cv': 5,
#  'error_score': nan,
#  'estimator__bootstrap': True,
#  'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': None,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_leaf_nodes': None,
#  'estimator__max_samples': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__n_estimators': 100,
#  'estimator__n_jobs': None,
#  'estimator__oob_score': False,
#  'estimator__random_state': 42,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': RandomForestClassifier(random_state=42),
#  'n_jobs': -1,
#  'param_grid': {'n_estimators': [100, 200, 300],
#   'max_depth': [None, 10, 20, 30],
#   'min_samples_split': [2, 5, 10],
#   'min_samples_leaf': [1, 2, 4]},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
#  'scoring': 'f1',
#  'verbose': 2}

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_rf_smote = grid_search_rf_smote.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_rf_smote), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_rf_smote))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_rf_smote))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_rf_smote, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_rf_smote, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_rf_smote, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9995088948194866
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.91      0.97      0.94       603
#
#     accuracy                           1.00    154753
#    macro avg       0.95      0.98      0.97    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9574468085106383
# F1/2-Score (harmonik dari F1 dan F2): 0.9481361426256079

# %% [markdown]
# ### Random Forest Adasyn

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model
rf = RandomForestClassifier(random_state=42)

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Inisialisasi GridSearchCV
grid_search_rf_adasyn = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2 
)

start = time.time()
# Jalankan GridSearch
grid_search_rf_adasyn.fit(X_train_adasyn, y_train_adasyn)

end = time.time()
duration = end - start

# Tampilkan hasil terbaik
print("Best Params:", grid_search_rf_adasyn.best_params_)
print("Best Cross-Validated Accuracy:", grid_search_rf_adasyn.best_score_)
print(f"Durasi training: {duration:.2f} detik")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=11.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 6.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=11.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=12.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 8.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 4.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 4.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 4.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=11.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.9min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=11.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=11.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=12.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 7.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 8.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=11.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=11.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=11.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.6min
# Best Params: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best Cross-Validated Accuracy: 0.976279484219076
# Durasi training: 4801.95 detik

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_rf_adasyn = grid_search_rf_adasyn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_rf_adasyn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_rf_adasyn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_rf_adasyn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_rf_adasyn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_rf_adasyn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_rf_adasyn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9909016303399611
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    154150
#            1       0.30      0.98      0.46       603
#
#     accuracy                           0.99    154753
#    macro avg       0.65      0.99      0.73    154753
# weighted avg       1.00      0.99      0.99    154753
#
# F2-Score: 0.6734044969339087
# F1/2-Score (harmonik dari F1 dan F2): 0.5446362968405584

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model
rf = RandomForestClassifier(random_state=42)

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Inisialisasi GridSearchCV
grid_search_rf_enn = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2 
)


start_rf_enn = time.time()
# Jalankan GridSearch
grid_search_rf_enn.fit(X_train_enn, y_train_enn)

end_rf_enn = time.time()
duration_rf_enn = end - start

# Tampilkan hasil terbaik
print("Best Params:", grid_search_rf_enn.best_params_)
print("Best Cross-Validated Accuracy:", grid_search_rf_enn.best_score_)
print(f"Durasi training: {duration_rf_enn:.2f} detik")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.7min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 7.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 7.0min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.9min
# Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Cross-Validated Accuracy: 0.9999443867262678
# Durasi training: 4801.95 detik
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 7.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.9min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 6.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=10.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.8min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 7.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 4.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 7.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.6min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.9min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.9min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 7.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=10.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.9min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.0min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 7.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=10.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=10.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 6.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.6min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=10.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 7.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.6min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=10.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 4.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 4.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.3min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 6.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 6.1min

# %%
duration_rf_enn = end_rf_enn - start_rf_enn
print(duration_rf_enn)
# Out:
# 4411.803577899933

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_rf_enn = grid_search_rf_enn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_rf_enn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_rf_enn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_rf_enn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_rf_enn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_rf_enn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_rf_enn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.99925041840869
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.85      0.98      0.91       603
#
#     accuracy                           1.00    154753
#    macro avg       0.93      0.99      0.96    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9500805152979066
# F1/2-Score (harmonik dari F1 dan F2): 0.929866036249015

# %% [markdown]
# ## Hyperparameter Tuning XGBoost

# %% [markdown]
# ## Xgboost SMOTE

# %% [markdown]
# ### XGBoost dengan SMOTE

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model XGBoost
xgb = XGBClassifier(eval_metric='logloss', random_state=42)

# Hyperparameter grid untuk XGBoost
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0]
}

# Inisialisasi GridSearchCV
grid_search_xgb_smote = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid_xgb,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

# Jalankan GridSearch pada data SMOTE


start_xgb_smote = time.time()
# Jalankan GridSearch
grid_search_xgb_smote.fit(X_train_smote, y_train_smote)

end_xgb_smote = time.time()
duration_xgb_smote = end_xgb_smote - start_xgb_smote

# Tampilkan hasil terbaik
print("Best Params:", grid_search_xgb_smote.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_xgb_smote.best_score_)
print(f"Durasi training: {duration_xgb_smote:.2f} detik")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Params: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 300, 'subsample': 1.0}
# Best Cross-Validated F1 Score: 0.9997470595589381
# Durasi training: 193.36 detik
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  25.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  23.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  26.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  28.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  21.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  36.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  29.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  40.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  14.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  37.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  38.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  37.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  25.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  23.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  41.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  29.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   7.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  39.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  23.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  29.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  40.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  22.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  36.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  38.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  24.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  35.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  25.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  21.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  26.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  24.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  35.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  26.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  26.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  24.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  32.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  24.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  18.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  23.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  27.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  12.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  18.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  19.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  24.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  27.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  26.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  25.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  21.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  26.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  26.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  32.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  19.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  17.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  25.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  31.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  25.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  12.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  23.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  24.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  27.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  27.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  31.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  25.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  24.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  19.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  24.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  17.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  19.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  24.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  29.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  25.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  19.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  28.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  22.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  39.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  21.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  37.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  26.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  41.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  37.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  25.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  41.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  33.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  21.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  40.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  23.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  24.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  20.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  10.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  18.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  25.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  25.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  21.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  32.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  23.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  15.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  25.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  10.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  25.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  23.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  16.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  16.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  19.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  36.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  37.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  23.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  29.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  26.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  20.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  23.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  17.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  30.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  40.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  17.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  27.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  35.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  21.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  37.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  25.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  27.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  22.5s

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_xgb_smote = grid_search_xgb_smote.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_xgb_smote), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_xgb_smote))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_xgb_smote))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_xgb_smote, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_xgb_smote, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_xgb_smote, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9994313518962475
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.89      0.98      0.93       603
#
#     accuracy                           1.00    154753
#    macro avg       0.94      0.99      0.97    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9577235772357724
# F1/2-Score (harmonik dari F1 dan F2): 0.9439102564102564

# %% [markdown]
# ### XGboost with ADASYN

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model XGBoost
xgb = XGBClassifier(eval_metric='logloss', random_state=42)

# Hyperparameter grid untuk XGBoost
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0]
}

# Inisialisasi GridSearchCV
grid_search_xgb_adasyn = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid_xgb,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_xgb_adasyn = time.time()
# Jalankan GridSearch
grid_search_xgb_adasyn.fit(X_train_adasyn, y_train_adasyn)

end_xgb_adasyn = time.time()
duration_xgb_adasyn = end_xgb_adasyn - start_xgb_adasyn

# Tampilkan hasil terbaik
print("Best Params:", grid_search_xgb_adasyn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_xgb_adasyn.best_score_)
print(f"Durasi training: {duration_xgb_adasyn:.2f} detik")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Params: {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.6}
# Best Cross-Validated F1 Score: 0.9805181488918528
# Durasi training: 165.05 detik
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  25.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  27.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  34.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  29.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  35.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  24.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  22.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  17.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  32.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  34.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  27.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  36.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  12.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  27.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  25.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  20.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  35.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  24.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  19.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  32.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  31.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  17.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  14.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  27.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  23.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  20.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  18.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  23.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  25.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  24.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  34.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  24.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  25.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  25.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  14.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  25.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  35.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  22.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  25.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  26.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  32.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  17.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  31.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   8.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  24.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  13.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  17.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  13.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  15.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  24.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  14.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  17.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   8.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  22.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  16.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  16.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  24.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  16.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=   9.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  36.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  35.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  35.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  20.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  35.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  22.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  23.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  25.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  29.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  31.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  35.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  21.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  28.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  19.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  37.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  22.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  27.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  36.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  31.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  28.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  38.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  25.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  26.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  20.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  36.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  18.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   8.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  26.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  19.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  23.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  16.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  15.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  24.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  15.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  27.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  18.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  19.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  10.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  19.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  15.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  17.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  34.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  14.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  19.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  21.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  18.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  23.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  27.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  19.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  29.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  31.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  34.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  17.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  29.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  33.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  11.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  35.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  22.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  26.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  21.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  28.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  11.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  31.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  33.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  19.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  24.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  25.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  30.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  35.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  20.8s

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_xgb_adasyn = grid_search_xgb_adasyn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_xgb_adasyn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_xgb_adasyn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_xgb_adasyn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_xgb_adasyn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_xgb_adasyn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_xgb_adasyn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9974410835331141
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.61      0.97      0.75       603
#
#     accuracy                           1.00    154753
#    macro avg       0.80      0.99      0.87    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.8686001775673277
# F1/2-Score (harmonik dari F1 dan F2): 0.8036692223439211

# %% [markdown]
# ### XGBoost with ENN

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model XGBoost
xgb = XGBClassifier(eval_metric='logloss', random_state=42)

# Hyperparameter grid untuk XGBoost
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0]
}

# Inisialisasi GridSearchCV
grid_search_xgb_enn = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid_xgb,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_xgb_enn = time.time()
# Jalankan GridSearch
grid_search_xgb_enn.fit(X_train_enn, y_train_enn)

end_xgb_enn = time.time()
duration_xgb_enn = end_xgb_enn - start_xgb_enn

# Tampilkan hasil terbaik
print("Best Params:", grid_search_xgb_enn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_xgb_enn.best_score_)
print(f"Durasi training: {duration_xgb_enn:.2f} detik")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Params: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 300, 'subsample': 1.0}
# Best Cross-Validated F1 Score: 0.9999360481053621
# Durasi training: 192.03 detik

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_xgb_enn = grid_search_xgb_enn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_xgb_enn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_xgb_enn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_xgb_enn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_xgb_enn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_xgb_enn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_xgb_enn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9992245707676103
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.85      0.98      0.91       603
#
#     accuracy                           1.00    154753
#    macro avg       0.92      0.99      0.95    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9498553519768563
# F1/2-Score (harmonik dari F1 dan F2): 0.9283694627709707
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  14.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  16.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  11.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  19.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  36.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  37.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  21.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  10.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  31.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  26.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  25.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  31.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  26.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  30.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  38.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  26.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  29.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  38.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  15.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  30.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  38.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  22.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  35.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  38.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  15.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  29.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  28.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  21.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  37.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  36.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=  14.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  20.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  30.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  21.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  23.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=   9.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6; total time=  24.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  32.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  23.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  23.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  17.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  14.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  16.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  26.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  15.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  13.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  32.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  25.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.4s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  16.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  27.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  22.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.6s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  14.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  29.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  10.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  26.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=  16.5s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  21.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  17.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=   9.8s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  29.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  10.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   8.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  16.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  16.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  21.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  18.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  15.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.6; total time=   9.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  16.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=  21.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  16.4s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  28.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  28.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  20.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  38.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  21.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  36.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  24.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  38.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  21.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  29.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  28.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  22.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=1.0; total time=  37.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  30.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  34.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  39.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  23.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.9s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  34.5s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.8; total time=  14.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  38.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=  24.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=  30.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.6; total time=  26.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  11.1s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  15.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  31.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  17.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.6; total time=  12.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  21.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.0s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  11.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  26.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=  22.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.6; total time=  11.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.6; total time=  15.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.8; total time=  18.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.6s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  13.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  30.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8; total time=  25.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=   7.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  14.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=1.0; total time=  16.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  14.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1.0; total time=  20.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  16.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  28.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  30.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=  21.4s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.1s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   9.3s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  20.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  22.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=  36.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  25.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  19.2s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=  20.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  23.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  29.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  26.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  10.9s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.5s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  22.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=  16.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  29.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  38.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=  30.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=  14.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=300, subsample=1.0; total time=  35.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  27.3s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=  12.2s
# [CV] END learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.2s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  28.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  29.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.6; total time=  21.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.6; total time=   8.9s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.6; total time=  23.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  22.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  37.2s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.6; total time=  11.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=300, subsample=1.0; total time=  29.0s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.8s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6; total time=  24.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  29.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=1.0; total time=  28.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  18.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.6; total time=  38.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=  13.0s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=  36.7s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=  24.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1.0; total time=  19.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=200, subsample=0.6; total time=  26.5s
# [CV] END learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1.0; total time=  20.1s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.9s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  21.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=  26.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=  30.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  13.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.8; total time=  36.3s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=  12.7s
# [CV] END learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.8; total time=  21.8s

# %% [markdown]
# ## HyperParameter Tuning Adaboost

# %% [markdown]
# ### Adaboost with Smote

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

ada = AdaBoostClassifier(random_state=42)

# Hyperparameter grid untuk AdaBoost
param_grid_ada = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.01, 0.1, 0.2],
}

# Inisialisasi GridSearchCV
grid_search_ada_smote = GridSearchCV(
    estimator=ada,
    param_grid=param_grid_ada,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_ada_smote = time.time()
# Jalankan GridSearch
grid_search_ada_smote.fit(X_train_smote, y_train_smote)

end_ada_smote = time.time()
duration_ada_smote = end_ada_smote - start_ada_smote

# Tampilkan hasil terbaik
print("Best Params:", grid_search_ada_smote.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_ada_smote.best_score_)
print(f"Durasi training: {duration_ada_smote:.2f} detik")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Params: {'learning_rate': 0.2, 'n_estimators': 200}
# Best Cross-Validated F1 Score: 0.8524680265682182
# Durasi training: 314.40 detik
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  54.1s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  57.2s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  57.2s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.2min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  47.0s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.5min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  48.3s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.5min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.5min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  51.0s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.7min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  48.8s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.9min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  48.9s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.9min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.7min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  49.2s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.0min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.7min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.8min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  49.2s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.1min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  49.3s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.2min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  55.7s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.2min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  53.6s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.3min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  52.5s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  56.0s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_ada_smote = grid_search_ada_smote.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_ada_smote), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_ada_smote))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_ada_smote))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_ada_smote, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_ada_smote, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_ada_smote, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.766641034422596
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87    154150
#            1       0.01      0.89      0.03       603
#
#     accuracy                           0.77    154753
#    macro avg       0.51      0.83      0.45    154753
# weighted avg       1.00      0.77      0.86    154753
#
# F2-Score: 0.06872852233676977
# F1/2-Score (harmonik dari F1 dan F2): 0.04061944656004062

# %% [markdown]
# ### Adaboost with ADASYN

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

ada = AdaBoostClassifier(random_state=42)

param_grid_ada = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.01, 0.1, 0.2],
}

grid_search_ada_adasyn = GridSearchCV(
    estimator=ada,
    param_grid=param_grid_ada,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_ada_adasyn = time.time()
# Jalankan GridSearch
grid_search_ada_adasyn.fit(X_train_adasyn, y_train_adasyn)

end_ada_adasyn = time.time()
duration_ada_adasyn = end_ada_adasyn - start_ada_adasyn

print("Best Params:", grid_search_ada_adasyn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_ada_adasyn.best_score_)
print(f"Durasi training: {duration_ada_adasyn:.2f} detik")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Params: {'learning_rate': 0.2, 'n_estimators': 200}
# Best Cross-Validated F1 Score: 0.8249437482052719
# Durasi training: 314.40 detik
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  50.3s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  55.5s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  55.0s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.6min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.9min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  49.9s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.4min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.3min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.2min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.4min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  47.6s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.6min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.4min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.8min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  49.5s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.0min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.8min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  48.1s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.9min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  48.2s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.1min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.7min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  51.9s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.1min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.9min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 3.0min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.9min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 3.0min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 3.0min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  51.9s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.1min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  48.8s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.3min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  48.5s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.3min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  51.2s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  54.6s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  57.9s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.6min

# %%
duration_ada_adasyn = end_ada_adasyn - start_ada_adasyn
duration_ada_adasyn
# Out:
# 353.6846296787262

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_ada_adasyn = grid_search_ada_adasyn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_ada_adasyn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_ada_adasyn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_ada_adasyn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_ada_adasyn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_ada_adasyn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_ada_adasyn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.6867265901145697
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.81    154150
#            1       0.01      0.95      0.02       603
#
#     accuracy                           0.69    154753
#    macro avg       0.51      0.82      0.42    154753
# weighted avg       1.00      0.69      0.81    154753
#
# F2-Score: 0.05589144423491903
# F1/2-Score (harmonik dari F1 dan F2): 0.03276091935686042

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

ada = AdaBoostClassifier(random_state=42)

param_grid_ada = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.01, 0.1, 0.2],
}

grid_search_ada_enn = GridSearchCV(
    estimator=ada,
    param_grid=param_grid_ada,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_ada_enn = time.time()
# Jalankan GridSearch
grid_search_ada_enn.fit(X_train_enn, y_train_enn)

end_ada_enn = time.time()
duration_ada_enn = end_ada_enn - start_ada_enn

print("Best Params:", grid_search_ada_enn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_ada_enn.best_score_)
print(f"Durasi training: {duration_ada_enn:.2f} detik")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Params: {'learning_rate': 0.2, 'n_estimators': 200}
# Best Cross-Validated F1 Score: 0.8528832155479644
# Durasi training: 305.34 detik
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  54.8s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  56.7s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  55.2s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.5min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.6min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.8min
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 1.9min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.2min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  46.9s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.5min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  46.9s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time= 1.5min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.3min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.4min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.4min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ................learning_rate=0.1, n_estimators=150; total time= 2.4min
# [CV] END ...............learning_rate=0.01, n_estimators=150; total time= 2.5min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.6min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.6min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.6min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  47.3s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.9min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  47.2s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 1.9min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.7min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.7min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  47.3s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.0min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  47.8s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.0min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  48.1s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time= 2.0min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 2.8min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 2.9min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  50.2s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  49.4s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  50.2s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.4min
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=  48.3s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.5min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  54.4s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time= 2.5min

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_ada_enn = grid_search_ada_enn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_ada_enn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_ada_enn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_ada_enn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_ada_enn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_ada_enn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_ada_enn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.766641034422596
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87    154150
#            1       0.01      0.89      0.03       603
#
#     accuracy                           0.77    154753
#    macro avg       0.51      0.83      0.45    154753
# weighted avg       1.00      0.77      0.86    154753
#
# F2-Score: 0.06872852233676977
# F1/2-Score (harmonik dari F1 dan F2): 0.04061944656004062

# %% [markdown]
# ## Hyperparameter LightGBM

# %% [markdown]
# ### LGBM with SMOTE

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

lgbm = LGBMClassifier(random_state=42)

param_grid_lgbm = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1]
}

grid_search_lgbm_smote = GridSearchCV(
    estimator=lgbm,
    param_grid=param_grid_lgbm,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_lgbm_smote = time.time()
# Jalankan GridSearch
grid_search_lgbm_smote.fit(X_train_smote, y_train_smote)

end_lgbm_smote = time.time()
duration_lgbm_smote = end_lgbm_smote - start_lgbm_smote

print("Best Params:", grid_search_lgbm_smote.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_lgbm_smote.best_score_)
print(f"Durasi training: {duration_lgbm_smote:.2f} detik")
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.338898 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.5min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.412149 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.5min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.328748 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.6min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.346908 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575492, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.6min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.352904 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.6min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.367384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.472401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.543724 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575492, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.406627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.9min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.456157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.9min
# [LightGBM] [Info] Number of positive: 359683, number of negative: 359683
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 719366, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best Params: {'learning_rate': 0.1, 'n_estimators': 100}
# Best Cross-Validated F1 Score: 0.9990678202188702
# Durasi training: 1051.60 detik
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.351376 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.1min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.476538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.1min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.455532 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.1min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.350728 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575492, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.1min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.316916 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.3min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.352604 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.387603 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287747, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.384757 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500001 -> initscore=0.000003
# [LightGBM] [Info] Start training from score 0.000003
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.206471 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575492, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287746, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.503922 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575493, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499999 -> initscore=-0.000003
# [LightGBM] [Info] Start training from score -0.000003
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_lgbm_smote = grid_search_lgbm_smote.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_lgbm_smote), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_lgbm_smote))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_lgbm_smote))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_lgbm_smote, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_lgbm_smote, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_lgbm_smote, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9983263652400923
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.70      0.99      0.82       603
#
#     accuracy                           1.00    154753
#    macro avg       0.85      0.99      0.91    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9131368937998773
# F1/2-Score (harmonik dari F1 dan F2): 0.8647627352663324

# %% [markdown]
# ### LGBM with Adasyn

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

lgbm = LGBMClassifier(random_state=42)

param_grid_lgbm = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1]
}

grid_search_lgbm_adasyn = GridSearchCV(
    estimator=lgbm,
    param_grid=param_grid_lgbm,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_lgbm_adasyn = time.time()

grid_search_lgbm_adasyn.fit(X_train_adasyn, y_train_adasyn)

end_lgbm_adasyn = time.time()
duration_lgbm_adasyn = end_lgbm_adasyn - start_lgbm_adasyn

print("Best Params:", grid_search_lgbm_adasyn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_lgbm_adasyn.best_score_)
print(f"Durasi training: {duration_lgbm_adasyn:.2f} detik")
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.490362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.255874 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287684, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.387685 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499945 -> initscore=-0.000219
# [LightGBM] [Info] Start training from score -0.000219
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.398821 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.345908 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575432, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000215
# [LightGBM] [Info] Start training from score -0.000215
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.9min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.249943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=12.0min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.463944 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=12.0min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.431295 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575432, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000215
# [LightGBM] [Info] Start training from score -0.000215
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=12.0min
# [LightGBM] [Info] Number of positive: 287684, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.315311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499945 -> initscore=-0.000219
# [LightGBM] [Info] Start training from score -0.000219
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=12.0min
# [LightGBM] [Info] Number of positive: 359606, number of negative: 359683
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002879 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 719289, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000214
# [LightGBM] [Info] Start training from score -0.000214
# Best Params: {'learning_rate': 0.1, 'n_estimators': 100}
# Best Cross-Validated F1 Score: 0.9801679360156802
# Durasi training: 1060.28 detik
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.370324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.355876 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.383780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575432, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000215
# [LightGBM] [Info] Start training from score -0.000215
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.444199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287684, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.398902 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499945 -> initscore=-0.000219
# [LightGBM] [Info] Start training from score -0.000219
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.390315 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.410175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287684, number of negative: 287747
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.340302 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499945 -> initscore=-0.000219
# [LightGBM] [Info] Start training from score -0.000219
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287747
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.288149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575432, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000215
# [LightGBM] [Info] Start training from score -0.000215
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.6min
# [LightGBM] [Info] Number of positive: 287685, number of negative: 287746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.426765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2549
# [LightGBM] [Info] Number of data points in the train set: 575431, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499947 -> initscore=-0.000212
# [LightGBM] [Info] Start training from score -0.000212
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.6min

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_lgbm_adasyn = grid_search_lgbm_adasyn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_lgbm_adasyn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_lgbm_adasyn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_lgbm_adasyn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_lgbm_adasyn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_lgbm_adasyn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_lgbm_adasyn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.9979774220855169
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.66      0.99      0.79       603
#
#     accuracy                           1.00    154753
#    macro avg       0.83      0.99      0.90    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.8972809667673716
# F1/2-Score (harmonik dari F1 dan F2): 0.8410619469026549

# %%
grid_search_lgbm_adasyn.best_params_

# %% [markdown]
# ### LGBM with ENN

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

lgbm = LGBMClassifier(random_state=42)

param_grid_lgbm = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1]
}

grid_search_lgbm_enn = GridSearchCV(
    estimator=lgbm,
    param_grid=param_grid_lgbm,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

start_lgbm_enn = time.time()

grid_search_lgbm_enn.fit(X_train_enn, y_train_enn)

end_lgbm_enn = time.time()
duration_lgbm_enn = end_lgbm_enn - start_lgbm_enn

print("Best Params:", grid_search_lgbm_enn.best_params_)
print("Best Cross-Validated F1 Score:", grid_search_lgbm_enn.best_score_)
print(f"Durasi training: {duration_lgbm_enn:.2f} detik")
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287296
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.463183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500350 -> initscore=0.001402
# [LightGBM] [Info] Start training from score 0.001402
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.6min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.445157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.6min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.385820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.490189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287296
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421766 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500350 -> initscore=0.001402
# [LightGBM] [Info] Start training from score 0.001402
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.7min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031740 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287700, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.285155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500352 -> initscore=0.001409
# [LightGBM] [Info] Start training from score 0.001409
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.431899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.370593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=11.8min
# [LightGBM] [Info] Number of positive: 287700, number of negative: 287295
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.390597 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500352 -> initscore=0.001409
# [LightGBM] [Info] Start training from score 0.001409
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=11.9min
# [LightGBM] [Info] Number of positive: 359624, number of negative: 359119
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 718743, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# Best Params: {'learning_rate': 0.1, 'n_estimators': 100}
# Best Cross-Validated F1 Score: 0.9993996193179834
# Durasi training: 1054.31 detik
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.324165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.4min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.247885 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.4min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287296
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.381293 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500350 -> initscore=0.001402
# [LightGBM] [Info] Start training from score 0.001402
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.4min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.344093 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287700, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.397889 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500352 -> initscore=0.001409
# [LightGBM] [Info] Start training from score 0.001409
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287296
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.486710 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500350 -> initscore=0.001402
# [LightGBM] [Info] Start training from score 0.001402
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.449417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287700, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.417917 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574995, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500352 -> initscore=0.001409
# [LightGBM] [Info] Start training from score 0.001409
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.327508 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=17.5min
# [LightGBM] [Info] Number of positive: 287699, number of negative: 287295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.352831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 574994, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500351 -> initscore=0.001405
# [LightGBM] [Info] Start training from score 0.001405
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=17.5min

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, fbeta_score

y_pred_lgbm_enn = grid_search_lgbm_enn.predict(X_test_scaled)

# 1. Confusion Matrix
print("Confusion Matrix:")
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred_lgbm_enn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 2. Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_lgbm_enn))

# 3. Classification Report (berisi precision, recall, f1-score per kelas)
print("Classification Report:")
print(classification_report(y_test, y_pred_lgbm_enn))

# 4. F2-Score
f2 = fbeta_score(y_test, y_pred_lgbm_enn, beta=2, average='binary')  # binary → untuk dua kelas
print("F2-Score:", f2)

# 5. F1/2-Score (harmonic mean dari F1 dan F2 secara manual)
f1 = fbeta_score(y_test, y_pred_lgbm_enn, beta=1, average='binary')
f2 = fbeta_score(y_test, y_pred_lgbm_enn, beta=2, average='binary')
f1_2 = 2 * f1 * f2 / (f1 + f2) if (f1 + f2) != 0 else 0
print("F1/2-Score (harmonik dari F1 dan F2):", f1_2)
# Out:
# Confusion Matrix:
# Accuracy: 0.998274669957933
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    154150
#            1       0.70      0.99      0.82       603
#
#     accuracy                           1.00    154753
#    macro avg       0.85      0.99      0.91    154753
# weighted avg       1.00      1.00      1.00    154753
#
# F2-Score: 0.9099264705882353
# F1/2-Score (harmonik dari F1 dan F2): 0.8606824603347099

# %%
grid_search_lgbm_enn.best_params_

# %%
with open('lgbm_smote.pkl', 'wb') as f:
    pickle.dump(grid_search_lgbm_smote, f)
